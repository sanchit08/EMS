# %%
import tkinter as tk
from tkinter import messagebox
import mysql.connector
class LibraryManagement:
    def __init__(self, root):
        self.root = root
        self.root.title("Event Management System")
        root.geometry("1000x1000")

        heading_label = tk.Label(root, text="Event Management System", font=("Helvetica", 25, "bold"),bg="darkolivegreen",width=90)
        heading_label.pack(side="top", pady=20)
        
        add_button = tk.Button(root, text="Admin login", command=self.admin_actions,bg='darkolivegreen2',height= 5, width=30)
        add_button.pack(side="top", pady=50)
        add_button.place(relx=0.25, rely=0.4, anchor="center")

        delete_button = tk.Button(root, text="Vendor login", command=self.vendor_actions,bg='darkseagreen3',height= 5, width=30)
        delete_button.pack(side="top", pady=50)
        delete_button.place(relx=0.5, rely=0.6, anchor="center")

        viewall_button = tk.Button(root, text="User Login",command=self.user_actions,bg='darkorange2',height= 5, width=30)
        viewall_button.pack(side="top", pady=50)
        viewall_button.place(relx=0.7, rely=0.4, anchor="center")

        
        
    def admin_actions(self):

        admin_window = tk.Toplevel(self.root)
        admin_window.geometry("1000x1000")
        admin_window.title("Admin Actions")

        heading_label = tk.Label(admin_window, text="Event Management System", font=("Helvetica", 25, "bold"),bg="light blue",width=90)
        heading_label.pack(side="top", pady=20)

        user_label = tk.Label(admin_window, text="User ID",bg="blue" ,height=5, width=30)
        user_label.pack(side="top", pady=50)
        user_label.place(relx=0.3, rely=0.4, anchor="center")

        user_entry = tk.Entry(admin_window,font=("Helvetica", 12),width=30)
        user_entry.pack(side="top", pady=50)
        user_entry.place(relx=0.7, rely=0.4, anchor="center")

        pass_label = tk.Label(admin_window, text="Password",bg="blue", height=5, width=30)
        pass_label.pack(side="top", pady=50)
        pass_label.place(relx=0.3, rely=0.6, anchor="center")

        pass_entry = tk.Entry(admin_window,font=("Helvetica", 12),width=30)
        pass_entry.pack(side="top", pady=50)
        pass_entry.place(relx=0.7, rely=0.6, anchor="center")

        cancel_button = tk.Button(admin_window, text="Cancel",height= 3, width=20)
        cancel_button.pack(side="top", pady=20)
        cancel_button.place(relx=0.4, rely=0.8, anchor="center")

        Login_button = tk.Button(admin_window, command=self.welcome_admin,text="Login",height= 3, width=20)
        Login_button.pack(side="top", pady=20)
        Login_button.place(relx=0.7, rely=0.8, anchor="center")
    
    def vendor_actions(self):

        admin_window = tk.Toplevel(self.root)
        admin_window.geometry("1000x1000")
        admin_window.title("Vendor Actions")

        Chart_button = tk.Button(admin_window, text="Chart",height= 3, width=20,bg='grey')
        Chart_button.pack(side="top", pady=20)
        Chart_button.place(relx=0.1, rely=0.1, anchor="center")

        back_button = tk.Button(admin_window, text="Back",height= 3, width=20,bg='grey')
        back_button.pack(side="top", pady=20)
        back_button.place(relx=0.9, rely=0.1, anchor="center")

        heading_label = tk.Label(admin_window, text="Event Management System", font=("Helvetica", 25, "bold"),bg="light blue",width=90)
        heading_label.pack(side="top", pady=20)
        heading_label.place(relx=0.5, rely=0.2, anchor="center")

        user_label = tk.Label(admin_window, text="User ID",bg="blue" ,height=5, width=30)
        user_label.pack(side="top", pady=50)
        user_label.place(relx=0.3, rely=0.4, anchor="center")

        user_entry = tk.Entry(admin_window,font=("Helvetica", 12),width=30)
        user_entry.pack(side="top", pady=50)
        user_entry.place(relx=0.7, rely=0.4, anchor="center")

        pass_label = tk.Label(admin_window, text="Password",bg="blue", height=5, width=30)
        pass_label.pack(side="top", pady=50)
        pass_label.place(relx=0.3, rely=0.6, anchor="center")

        pass_entry = tk.Entry(admin_window,font=("Helvetica", 12),width=30)
        pass_entry.pack(side="top", pady=50)
        pass_entry.place(relx=0.7, rely=0.6, anchor="center")

        cancel_button = tk.Button(admin_window, text="Cancel",height= 3, width=20,bg='grey')
        cancel_button.pack(side="top", pady=20)
        cancel_button.place(relx=0.4, rely=0.8, anchor="center")

        Login_button = tk.Button(admin_window, command= self.welcome_vendor,text="Login",height= 3, width=20,bg='grey')
        Login_button.pack(side="top", pady=20)
        Login_button.place(relx=0.7, rely=0.8, anchor="center")
    
    def user_actions(self):

        user_window = tk.Toplevel(self.root)
        user_window.geometry("1000x1000")
        user_window.title("Vendor Actions")

        Chart_button = tk.Button(user_window, text="Chart",height= 3, width=20,bg='grey')
        Chart_button.pack(side="top", pady=20)
        Chart_button.place(relx=0.1, rely=0.1, anchor="center")

        back_button = tk.Button(user_window, text="Back",height= 3, width=20,bg='grey')
        back_button.pack(side="top", pady=20)
        back_button.place(relx=0.9, rely=0.1, anchor="center")

        heading_label = tk.Label(user_window, text="Event Management System", font=("Helvetica", 25, "bold"),bg="light blue",width=90)
        heading_label.pack(side="top", pady=20)
        heading_label.place(relx=0.5, rely=0.2, anchor="center")

        user_label = tk.Label(user_window, text="User ID",bg="blue" ,height=5, width=30)
        user_label.pack(side="top", pady=50)
        user_label.place(relx=0.3, rely=0.4, anchor="center")

        user_entry = tk.Entry(user_window,font=("Helvetica", 12),width=30)
        user_entry.pack(side="top", pady=50)
        user_entry.place(relx=0.7, rely=0.4, anchor="center")

        pass_label = tk.Label(user_window, text="Password",bg="blue", height=5, width=30)
        pass_label.pack(side="top", pady=50)
        pass_label.place(relx=0.3, rely=0.6, anchor="center")

        pass_entry = tk.Entry(user_window,font=("Helvetica", 12),width=30)
        pass_entry.pack(side="top", pady=50)
        pass_entry.place(relx=0.7, rely=0.6, anchor="center")

        cancel_button = tk.Button(user_window, text="Cancel",height= 3, width=20,bg='grey')
        cancel_button.pack(side="top", pady=20)
        cancel_button.place(relx=0.4, rely=0.8, anchor="center")

        Login_button = tk.Button(user_window,command=self.welcome_user,text="Login",height= 3, width=20,bg='grey')
        Login_button.pack(side="top", pady=20)
        Login_button.place(relx=0.7, rely=0.8, anchor="center")
    
    def welcome_vendor(self):

        welcome_window = tk.Toplevel(self.root)
        welcome_window.geometry("1000x1000")
        welcome_window.title("welcome vendor Actions")

        heading_label = tk.Label(welcome_window, text="Welcome vendor", font=("Helvetica", 25, "bold"),bg="light blue",width=90)
        heading_label.pack(side="top", pady=20)
        
        add_button = tk.Button(welcome_window, text="Your item", command=self.admin_actions,height= 5, width=30)
        add_button.pack(side="top", pady=50)
        add_button.place(relx=0.5, rely=0.2, anchor="center")

        delete_button = tk.Button(welcome_window, text="Add new Item", command=self.vendor_actions,height= 5, width=30)
        delete_button.pack(side="top", pady=50)
        delete_button.place(relx=0.5, rely=0.4, anchor="center")

        viewall_button = tk.Button(welcome_window, text="Transaction",command=self.user_actions,height= 5, width=30)
        viewall_button.pack(side="top", pady=50)
        viewall_button.place(relx=0.5, rely=0.6, anchor="center")

        viewall_button = tk.Button(welcome_window, text="LogOut",command=self.user_actions,height= 5, width=30)
        viewall_button.pack(side="top", pady=50)
        viewall_button.place(relx=0.5, rely=0.8, anchor="center")

    def welcome_admin(self):
        
        weladmin_window = tk.Toplevel(self.root)
        weladmin_window.geometry("1000x1000")
        weladmin_window.title("Vendor Actions")

        Chart_button = tk.Button(weladmin_window, text="Home",height= 3, width=20,bg='grey')
        Chart_button.pack(side="top", pady=20)
        Chart_button.place(relx=0.1, rely=0.25, anchor="center")

        back_button = tk.Button(weladmin_window, text="LogOut",command=self.admin_actions,height= 3, width=20,bg='grey')
        back_button.pack(side="top", pady=20)
        back_button.place(relx=0.9, rely=0.25, anchor="center")

        heading_label = tk.Label(weladmin_window, text="Welcome Admin", font=("Helvetica", 25, "bold"),bg="light blue",width=90)
        heading_label.pack(side="top", pady=20)
        heading_label.place(relx=0.5, rely=0.5, anchor="center")

        maintain_button = tk.Button(weladmin_window, text="Maintain User",height= 3, width=20,bg='burlywood3')
        maintain_button.pack(side="top", pady=20)
        maintain_button.place(relx=0.3, rely=0.7, anchor="center")

        vendor_button = tk.Button(weladmin_window, text="Maintain Vendor",height= 3, width=20,bg='burlywood3')
        vendor_button.pack(side="top", pady=20)
        vendor_button.place(relx=0.7, rely=0.7, anchor="center")
    
    def welcome_user(self):

        weluser_window = tk.Toplevel(self.root)
        weluser_window.geometry("1000x1000")
        weluser_window.title("Vendor Actions")

        heading_label = tk.Label(weluser_window, text="Welcome User", font=("Helvetica", 25, "bold"),bg="light blue",width=90)
        heading_label.pack(side="top", pady=20)
        heading_label.place(relx=0.5, rely=0.2, anchor="center")

        add_button = tk.Button(weluser_window, text="Vendor",bg='darkolivegreen2',height= 5, width=30)
        add_button.pack(side="top", pady=50)
        add_button.place(relx=0.25, rely=0.4, anchor="center")

        delete_button = tk.Button(weluser_window, text="Cart",command=self.cart,bg='darkseagreen3',height= 5, width=30)
        delete_button.pack(side="top", pady=50)
        delete_button.place(relx=0.7, rely=0.4, anchor="center")

        add_button = tk.Button(weluser_window, text="Guest List",bg='darkseagreen3',height= 5, width=30)
        add_button.pack(side="top", pady=50)
        add_button.place(relx=0.25, rely=0.6, anchor="center")

        delete_button = tk.Button(weluser_window, text="Order Status",bg='darkolivegreen2',height= 5, width=30)
        delete_button.pack(side="top", pady=50)
        delete_button.place(relx=0.7, rely=0.6, anchor="center")

        delete_button = tk.Button(weluser_window, text="LogOut", command=self.user_actions,bg='grey',height= 5, width=30)
        delete_button.pack(side="top", pady=50)
        delete_button.place(relx=0.5, rely=0.8, anchor="center")

    def cart(self):
        cart_window = tk.Toplevel(self.root)
        cart_window.geometry("1000x1000")
        cart_window.title("Vendor Actions")

        Chart_button = tk.Button(cart_window, text="Home",height= 3, width=20,bg='grey')
        Chart_button.pack(side="top", pady=20)
        Chart_button.place(relx=0.1, rely=0.1, anchor="center")

        Chart_button = tk.Button(cart_window, text="View Product",height= 3, width=20,bg='grey')
        Chart_button.pack(side="top", pady=20)
        Chart_button.place(relx=0.4, rely=0.1, anchor="center")

        Chart_button = tk.Button(cart_window, text="Request Item",height= 3, width=20,bg='grey')
        Chart_button.pack(side="top", pady=20)
        Chart_button.place(relx=0.65, rely=0.1, anchor="center")

        Chart_button = tk.Button(cart_window, text="LogOut",height= 3, width=20,bg='grey')
        Chart_button.pack(side="top", pady=20)
        Chart_button.place(relx=0.9, rely=0.1, anchor="center")


def main():
    root = tk.Tk()
    app = LibraryManagement(root)
    root.mainloop()

if __name__ == "__main__":
    main()
